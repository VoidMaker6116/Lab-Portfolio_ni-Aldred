# %% [markdown]
# ## Assignment
# Update the sample code and create the following methods

# %%
class Node:
    def __init__(self, value=None):
        self.value = value
        self.next = None

# %%
class LinkedList:
    def __init__(self):
        self.head = None

# %%
def insert_at_beginning(self, value):
    new_node = Node(value)
    if self.head:
        new_node.next = self.head
        self.head = new_node
    else:
        self.head = new_node
        self.tail = new_node
# Out:
# []

# %%
def insert_at_end(self, value):
    new_node = Node(value)
    if self.head:
        self.tail.next = new_node
        self.tail = new_node
    else:
        self.head = new_node
        self.tail = new_node

# %%
def search(self, value):
    current_node = self.head
    while current_node:
        if current_node.value == value:
            return True
        else:
            current_node = current_node.next
    return False

# %% [markdown]
# ### Assignment
# ## Create the methodds
# # a. remove_beginning(self)
#     will return the data that was removed at the beginning
# # b. remove_at_end(self)
#     will return the data that was removed at the end
# # c. remove_at(self,data)
#     will return the data that was remove else return null if data not found

# %%
def remove_at_beginning(self):
    if self.head:
        removed_value = self.head.value
        self.head = self.head.next
        if not self.head:
            self.tail = None
        return removed_value
    return None

# %%
def remove_at_end(self):
    if self.head:
        if self.head == self.tail:
            removed_value = self.head.value
            self.head = None
            self.tail = None
            return removed_value
        current_node = self.head
        while current_node.next != self.tail:
            current_node = current_node.next
        removed_value = self.tail.value
        current_node.next = None
        self.tail = current_node
        return removed_value
    return None

# %%
def remove_at(self, value):
    if self.head:
        if self.head.value == value:
            return self.remove_at_beginning()
        current_node = self.head
        while current_node.next:
            if current_node.next.value == value:
                removed_value = current_node.next.value
                if current_node.next == self.tail:
                    self.tail = current_node
                current_node.next = current_node.next.next
                return removed_value
            current_node = current_node.next
    return None
